# %%
import pandas as pd
a=['varshitha','banu','name','sun']
r=pd.Series(a,index=[1,2,3,4])
print(r)
# Out:
# 1    varshitha
# 2         banu
# 3         name
# 4          sun
# dtype: object

# %%
import pandas as pd
df=pd.read_csv("/content/Stock Market Dataset.csv")
print(df)
# Out:
#       Unnamed: 0        Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 0              0  02-02-2024              2.079               NaN
# 1              1  01-02-2024              2.050          161340.0
# 2              2  31-01-2024              2.100          142860.0
# 3              3  30-01-2024              2.077          139750.0
# 4              4  29-01-2024              2.490            3590.0
# ...          ...         ...                ...               ...
# 1238        1238  08-02-2019              2.583          147880.0
# 1239        1239  07-02-2019              2.551          211790.0
# 1240        1240  06-02-2019              2.662           98330.0
# 1241        1241  05-02-2019              2.662           82250.0
# 1242        1242  04-02-2019              2.660          116490.0
#
#       Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol.  \
# 0               72.28             NaN        3.8215          NaN
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/Stock Market Dataset.csv",sep=" , ")
print(df)
# Out:
#      ,Date,Natural_Gas_Price,Natural_Gas_Vol.,Crude_oil_Price,Crude_oil_Vol.,Copper_Price,Copper_Vol.,Bitcoin_Price,Bitcoin_Vol.,Platinum_Price,Platinum_Vol.,Ethereum_Price,Ethereum_Vol.,S&P_500_Price,Nasdaq_100_Price,Nasdaq_100_Vol.,Apple_Price,Apple_Vol.,Tesla_Price,Tesla_Vol.,Microsoft_Price,Microsoft_Vol.,Silver_Price,Silver_Vol.,Google_Price,Google_Vol.,Nvidia_Price,Nvidia_Vol.,Berkshire_Price,Berkshire_Vol.,Netflix_Price,Netflix_Vol.,Amazon_Price,Amazon_Vol.,Meta_Price,Meta_Vol.,Gold_Price,Gold_Vol.
# 0     0,02-02-2024,2.079,,72.28,,3.8215,,"43,194.70"...
# 1     1,01-02-2024,2.05,161340.0,73.82,577940.0,3.85...
# 2     2,31-01-2024,2.1,142860.0,75.85,344490.0,3.906...
# 3     3,30-01-2024,2.077,139750.0,77.82,347240.0,3.9...
# 4     4,29-01-2024,2.49,3590.0,76.78,331930.0,3.879,...
# ...                                                 ...
# 1238  1238,08-02-2019,2.583,147880.0,52.72,621000.0,...
# 1239  1239,07-02-2019,2.551,211790.0,52.64,749010.0,...
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/Chandrayaan-3.txt")
print(df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                      Chandrayaan-3 (/ˌtʃʌndrəˈjɑːn/ CHUN-drə-YAHN) is the third mission in the Chandrayaan programme  \
# Chandrayaan-3 was launched from Satish Dhawan S...  and the lander touched down near the lunar sou...  making India the fourth country to successfull...  and the first to do so near the lunar south po...  it was hoped that the lander and rover would r...  on 22 September 2023                               but missed the wake-up call. On September 30                            the second lunar night began
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/Chandrayaan-3.txt",sep=" , ")
print(df)
# Out:
#    Chandrayaan-3 (/ˌtʃʌndrəˈjɑːn/ CHUN-drə-YAHN) is the third mission in the Chandrayaan programme, a series of lunar-exploration missions developed by the Indian Space Research Organisation (ISRO).[7] The mission consists of a lunar lander named Vikram and a lunar rover named Pragyan, similar to those launched aboard Chandrayaan-2 in 2019.
# 0   Chandrayaan-3 was launched from Satish Dhawan ...
# 1                                             History
# 2   On 22 July 2019, ISRO launched Chandrayaan-2 o...
# 3   The lunar south pole region holds particular i...
# 4   The European Space Tracking network (ESTRACK),...
# 5   For the first time on the lunar surface, a las...
# 6                                          Objectives
# 7   ISRO's mission objectives for the Chandrayaan-...
# 8   Engineering and implementing a lander to land ...
# 9   Observing and demonstrating the rover's drivin...
# 10  Conducting and observing experiments on the ma...
# ...

# %%
import pandas as pd
df=pd.read_excel("/content/job_data_merged_1.xlsx")
print(df)
# Out:
#       Unnamed: 0          Category Workplace  \
# 0              0  Business Analyst    Remote
# 1              1  Business Analyst    Remote
# 2              2  Business Analyst   On-site
# 3              3  Business Analyst   On-site
# 4              4  Business Analyst    Remote
# ...          ...               ...       ...
# 1090        1090             UI/UX    Remote
# 1091        1091             UI/UX    Remote
# 1092        1092             UI/UX   On-site
# 1093        1093             UI/UX   On-site
# 1094        1094             UI/UX    Remote
#
#                                           Location  \
# 0                                   United Kingdom
# 1                Makati, Metro Manila, Philippines
# 2     Al-Dajeej, Al Farwaniyah Governorate, Kuwait
# 3                  London, England, United Kingdom
# 4                                   United Kingdom
# ...                                            ...
# 1090                 Paris, ÃŽle-de-France, France
# ...

# %%
import pandas as pd
df=pd.read_excel("/content/job_data_merged_1.xlsx",sheet_name=1)
print(df)
# Out:
#    number  Category Category.1 Category.2 Category.3 Category.4
# 0       0  Category   Category   Category   Category   Category
# 1       1  Category   Category   Category   Category   Category
# 2       2  Category   Category   Category   Category   Category
# 3       3  Category   Category   Category   Category   Category
# 4       4  Category   Category   Category   Category   Category
# 5       5  Category   Category   Category   Category   Category
# 6       6  Category   Category   Category   Category   Category
# 7       7  Category   Category   Category   Category   Category
# 8       8  Category   Category   Category   Category   Category
# 9       9  Category   Category   Category   Category   Category

# %%
import pandas as pd
df=pd.read_csv("/content/Stock Market Dataset.csv")
df.loc[1]
# Out:
# Unnamed: 0                     1
# Date                  01-02-2024
# Natural_Gas_Price           2.05
# Natural_Gas_Vol.        161340.0
# Crude_oil_Price            73.82
# Crude_oil_Vol.          577940.0
# Copper_Price              3.8535
# Copper_Vol.                  NaN
# Bitcoin_Price          43,081.40
# Bitcoin_Vol.             47690.0
# Platinum_Price             922.3
# Platinum_Vol.                NaN
# Ethereum_Price          2,304.28
# Ethereum_Vol.           323610.0
# S&P_500_Price           4,906.19
# Nasdaq_100_Price       17,344.71
# Nasdaq_100_Vol.      240640000.0
# Apple_Price               186.86
# Apple_Vol.            53490000.0
# Tesla_Price               188.86
# Tesla_Vol.            90680000.0
# Microsoft_Price           403.78
# Microsoft_Vol.        29230000.0
# Silver_Price              23.236
# Silver_Vol.              85160.0
# Google_Price              141.16
# Google_Vol.           37120000.0
# Nvidia_Price              630.27
# ...

# %%
df=pd.read_excel("/content/job_data_merged_1.xlsx")
mv=df['number'].mean()
df=df.fillna(mv)
print(mv)
# Out:
# 547.0

# %%
import pandas as pd
dfn=pd.read_excel("/content/job_data_merged_1.xlsx")
#dfn=dfn.drop_duplicates()
dfn.head(2)
dfn.shape
#print(dfn)
# Out:
# (1095, 17)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/Stock Market Dataset.csv")
first=df.head(10)
last=df.tail(10)
final=pd.concat([first,last],axis=0)
final.to_csv("final_stock_market.csv")
print(final.groupby(['Natural_Gas_Price'])['Natural_Gas_Vol.'].count())
#data_true_manual_testing=df.tail(10)
#for i in range(1095,17,-1):
  #data_true.drop[i],axis=0,implace=true
# Out:
# Natural_Gas_Price
# 2.050    1
# 2.077    1
# 2.079    0
# 2.100    1
# 2.419    1
# 2.450    1
# 2.490    1
# 2.551    1
# 2.571    1
# 2.573    1
# 2.575    1
# 2.583    1
# 2.625    1
# 2.641    1
# 2.642    1
# 2.660    1
# 2.662    2
# 2.688    1
# 2.712    1
# Name: Natural_Gas_Vol., dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
runs=np.array([100,50,91,78,89,25,34,19,9,10])
w=np.array([1,2,2,0,3,7,8,9,7,5])
plt.scatter(runs,w,color='orange')
#plt.plot(runs,w,color='orange')
plt.title('IndvsAus_score')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#generate array of 200 values between -pi and pi
tigar=np.linspace(-2*np.pi,2*np.pi,50)
print(tigar)
plt.plot(tigar,np.sin(tigar),color='black')#plt.plot(x,y,color,labels...)
plt.title("sin(x)")
# Out:
# [-6.28318531 -6.02672876 -5.77027222 -5.51381568 -5.25735913 -5.00090259
#  -4.74444605 -4.48798951 -4.23153296 -3.97507642 -3.71861988 -3.46216333
#  -3.20570679 -2.94925025 -2.6927937  -2.43633716 -2.17988062 -1.92342407
#  -1.66696753 -1.41051099 -1.15405444 -0.8975979  -0.64114136 -0.38468481
#  -0.12822827  0.12822827  0.38468481  0.64114136  0.8975979   1.15405444
#   1.41051099  1.66696753  1.92342407  2.17988062  2.43633716  2.6927937
#   2.94925025  3.20570679  3.46216333  3.71861988  3.97507642  4.23153296
#   4.48798951  4.74444605  5.00090259  5.25735913  5.51381568  5.77027222
#   6.02672876  6.28318531]
# Text(0.5, 1.0, 'sin(x)')

# %%
import numpy as np
import matplotlib.pyplot as plt
#creating x
overs=np.arange(5,50,5)
overs_a=np.arange(5,30,5)
#creating y
runs_i=np.array([25,51,84,131,160,189,220,250,267])
runs_a=np.array([15,41,94,110,151])
wickets=np.array([12,32,96])
#plotting
#plt.subplot(2,1,2)
plt.plot(overs,runs_i,color="blue",label='India')
plt.legend(loc='best')
#plt.subplot(2,1,1)
plt.plot(overs_a,runs_a,color="yellow",label='Aus')
#combining two graphs
plt.legend(loc='best')
#displaying the final graph
plt.show()

# %%
import matplotlib.pyplot as plt
a=[230,568,780,127,128]
b=[200,160,270,127,400]
years=[1,2,3,4]
profit_a=[(a[i]-a[i-1]) for i in range(1,len(a))]
profit_b=[(b[i]-b[i-1]) for i in range(1,len(b))]
plt.subplot(2,1,2)
plt.plot(years,profit_a,color='hotpink',linewidth='3',label='CompanyA',marker='*',ms='15',mec='k')
plt.subplot(2,1,1)
plt.plot(years,profit_b,color='black',linestyle='dotted',label='CompanyB',marker='H')
plt.show()

# %%
a=np.array([25,60,5,10])
labe=['AIML',"Python","Pandas","Numpy"]
plt.pie(a,labels=labe)
plt.show()

# %%
#explode
a=np.array([25,60,5,10])
labe=['AIML',"Python","Pandas","Numpy"]
explo=[0.2,0,0,0]
f=[10,20,17,2]
col=['yellow','magenta','green','skyblue']
plt.pie(a,labels=labe,colors=col,explode=explo,startangle=180,textprops={'fontsize':21})
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/temperature dataset for soc-2.csv")
print(df)
# Calculate the average temperature
avg_temp= df['Temperature (celsius)'].mean()
print(avg_temp)
#a=df.loc[df['']]
min_temp=df['Temperature (celsius)'].min()
print(min_temp)
max_temp=df['Temperature (celsius)'].max()
print(max_temp)
# Set the threshold temperature
threshold = 19.7
# Count the number of days where temperature exceeds the threshold
days_exceed_thresh= df[df['Temperature (celsius)'] > threshold].shape[0]
print(days_exceed_thresh)
date=np.arange(1,31)
temp=np.array([18.4,18.2,18.5,18.4,19.0,19.2,19.3,19.5,19.6,19.8,19.4,20.0,19.7,20.1,20.4,20.6,20.8,21.1,21.4,21.3,21.4,21.5,21.9,22.3,22.4,22.6,22.7,22.9,23.0,23.1])
plt.plot(temp,date,color='black',marker='*')
plt.ylabel('date')
plt.xlabel('temperature')
plt.title('Temperature_readings')
plt.show()
# Out:
#           Date  Temperature (celsius)
# 0   01-01-2023                   18.4
# 1   02-01-2023                   18.2
# 2   03-01-2023                   18.5
# 3   04-01-2023                   18.4
# 4   05-01-2023                   19.0
# 5   06-01-2023                   19.2
# 6   07-01-2023                   19.3
# 7   08-01-2023                   19.5
# 8   09-01-2023                   19.6
# 9   10-01-2023                   19.8
# 10  11-01-2023                   19.4
# 11  12-01-2023                   20.0
# 12  13-01-2023                   19.7
# 13  14-01-2023                   20.1
# 14  15-01-2023                   20.1
# 15  16-01-2023                   20.4
# 16  17-01-2023                   20.6
# 17  18-01-2023                   20.8
# 18  19-01-2023                   21.1
# 19  20-01-2023                   21.4
# 20  21-01-2023                   21.3
# 21  22-01-2023                   21.4
# 22  23-01-2023                   21.5
# 23  24-01-2023                   21.9
# ...

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("tips")
#create a scatter plot
sns.scatterplot(x="total_bill",y='tip',data=tips)
plt.title("Scatter Plot of Total Bill vs. Tip")
plt.xlabel("Total Bill($)")
plt.ylabel("Tip ($)")
plt.show()

# %%
#error will be generated
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("temperature dataset for soc-2")
#create a scatter plot
sns.scatterplot(x="Temperature (celsius)",y='Date',data=tips)
plt.title("Scatter Plot of Temperature vs. Date")
plt.xlabel("Temperature (celsius)")
plt.ylabel("Date")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-6dc724e6cb2f> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 #load example dataset
# ----> 4 tips=sns.load_dataset("temperature dataset for soc-2")
#       5 #create a scatter plot
#       6 sns.scatterplot(x="Temperature (celsius)",y='Date',data=tips)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: 'temperature dataset for soc-2' is not one of the example datasets.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
diamonds=sns.load_dataset("diamonds")
print(diamonds.head())
#create a scatter plot
sns.scatterplot(x="carat",y='price',data=diamonds)
plt.title("Scatter Plot of Carat vs. Price")
plt.xlabel("Carat")
plt.ylabel("Price")
plt.show()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import seaborn as sns
import matplotlib.pyplot
tips=sns.load_dataset("tips")
#create violin plot
sns.violinplot(x="day",y="total_bill",data=tips)
plt.title("Distribution of Total Bill by day")
plt.xlabel("Day of the week")
plt.ylabel("Total bill($)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
iris=sns.load_dataset("iris")
print(iris)
#compute correlation matrix
correlation_matrix=iris.corr()
#create a heat map of the correlation matrix
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
plt.title("correlation heatmap of iris dataset")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
flights=sns.load_dataset("flights")
print(flights)
#compute correlation matrix
correlation_matrix=flights.corr()
#create a heat map of the correlation matrix
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
plt.title("correlation heatmap of flights dataset")
plt.show()
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# <ipython-input-21-840f443203d3>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=flights.corr()
